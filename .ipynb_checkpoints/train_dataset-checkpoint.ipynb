# %%
import pandas as pd

# %%
test_df = pd.read_csv('service_desk_test.csv', encoding='utf-8', sep=';')

# %%
train_df = pd.read_csv('service_desk_train.csv', encoding='utf-8', sep=';')

# %%
test_df
# Out:
#        id                  Тип задачи  \
# 0    8566        Подзадача увольнение
# 1    8567        Подзадача увольнение
# 2    8568        Подзадача увольнение
# 3    8569        Подзадача увольнение
# 4    8570        Подзадача увольнение
# ..    ...                         ...
# 995  9561  Заявка на выход сотрудника
# 996  9562      Запрос на обслуживание
# 997  9563      Запрос на обслуживание
# 998  9564      Запрос на обслуживание
# 999  9565      Запрос на обслуживание
#
#                                                   Тема  Срок исполнения
# 0    HR. Долги по обучению, аккаунт BFTraining - Ко...              NaN
# 1    ДТиОР. Передать списки во FriendWork - Комисса...              NaN
# 2    ДТиОР. Установить замещение в СЭД - Комиссаров...              NaN
# 3    Служба безопасности. Увольнение - Комиссаров В...              NaN
# 4    ФинДеп. Уволить в ПУ - Комиссаров Вячеслав Дми...              NaN
# ...

# %%
print("Тренировочные данные:")
print(train_df.info())
print("\nТестовые данные:")
print(test_df.info())
# Out:
# Тренировочные данные:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8565 entries, 0 to 8564
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  8565 non-null   int64
#  1   Тип задачи                          8565 non-null   object
#  2   Тема                                8565 non-null   object
#  3   Срок исполнения                     0 non-null      float64
#  4   Пользовательское поле (Активность)  8135 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 334.7+ KB
# None
#
# Тестовые данные:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1000 non-null   int64
#  1   Тип задачи       1000 non-null   object
# ...

# %%
train_df
# Out:
#         id                Тип задачи  \
# 0        1    Запрос на обслуживание
# 1        2    Запрос на обслуживание
# 2        3  Заказ гостевого пропуска
# 3        4                 Подзадача
# 4        5                 Подзадача
# ...    ...                       ...
# 8560  8561      Подзадача увольнение
# 8561  8562      Подзадача увольнение
# 8562  8563      Подзадача увольнение
# 8563  8564      Подзадача увольнение
# 8564  8565      Подзадача увольнение
#
#                                                    Тема  Срок исполнения  \
# 0                            Утерян пропуск Рымарь В.С.              NaN
# 1                                  Доступ к ресурсу БФТ              NaN
# 2      Гостевой пропуск для Ермачкова Виктория Игоревна              NaN
# 3        ДИТ. Создание УЗ - Курочкина Лариса Викторовна              NaN
# 4     Оборудование - Курочкина Лариса Викторовна 9/1...              NaN
# ...
